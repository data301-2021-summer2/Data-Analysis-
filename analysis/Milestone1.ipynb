# %%
pwd
# Out:
# '/Users/aashishchilwal/Desktop/group32-project/data/raw'

# %%
import pandas as pd
pd.read_csv("outbreaks.csv")
# Out:
#      Year     Month       State                               Location  \
# 0    2015   January  California                             Restaurant
# 1    2015   January  California                   Fast Food Restaurant
# 2    2015   January  California                             Restaurant
# 3    2015   January  California                                    NaN
# 4    2015   January    Colorado                             Restaurant
# ..    ...       ...         ...                                    ...
# 892  2015  December   Wisconsin                             Restaurant
# 893  2015  December   Wisconsin                 Private Home/Residence
# 894  2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 895  2015  December   Wisconsin                   Fast Food Restaurant
# 896  2015  December     Wyoming                                    NaN
#
#        Food                 Species     Status  Illnesses  Hospitalizations  \
# ...
